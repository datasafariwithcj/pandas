# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
nba.head(n=7)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
nba.tail(n=4)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
nba.values #ndrrays, arrays of arrays
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
s.shape
# Out:
# (5,)

# %%
nba.shape
# Out:
# (458, 9)

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
nba.dtypes #integer column with even as single NaN will have dtype of float64
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
s.hasnans #DataFrame does not have this attribute.
# Out:
# False

# %%
nba.columns #Series does not have this attribute.
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
s.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1)]

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
s.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
revenue = pd.read_csv("revenue.csv", index_col = "Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
s = pd.Series([1, 2, 3, 4, 5])
s.sum()
# Out:
# np.int64(15)

# %%
revenue.sum() #Row total is the default setting
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum("columns") #use "Columns" or 1 for column total
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
revenue.sum().sum()
# Out:
# np.int64(16250)

# %%
nba["Name"] #Returns a view as a series
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
NBA_name = nba["Name"].copy
NBA_name
# Out:
# <bound method NDFrame.copy of 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object>

# %%
nba[["Name"]] # Returns a copy as a DataFrame
# Out:
#               Name
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# ..             ...
# 453   Shelvin Mack
# 454      Raul Neto
# 455   Tibor Pleiss
# 456    Jeff Withey
# 457            NaN
#
# [458 rows x 1 columns]

# %%
nba["Sport"] = "Basketball" # This will add a column only once no matter how many time the cell runs. 
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       Sport
# ...

# %%
nba.insert(9,"Testing","Ok",True) # This will add a column everytime the cell is ran.
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary Testing       Sport
# ...

# %%
nba["Salary"] = nba["Salary"]*2
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary Testing       Sport
# ...

# %%
nba["Team"].value_counts(normalize = True) * 100
# Out:
# Team
# New Orleans Pelicans      4.157549
# Memphis Grizzlies         3.938731
# New York Knicks           3.501094
# Milwaukee Bucks           3.501094
# Brooklyn Nets             3.282276
# Boston Celtics            3.282276
# Los Angeles Clippers      3.282276
# Los Angeles Lakers        3.282276
# Phoenix Suns              3.282276
# Sacramento Kings          3.282276
# Chicago Bulls             3.282276
# Philadelphia 76ers        3.282276
# Toronto Raptors           3.282276
# Golden State Warriors     3.282276
# Indiana Pacers            3.282276
# Detroit Pistons           3.282276
# Cleveland Cavaliers       3.282276
# Dallas Mavericks          3.282276
# Houston Rockets           3.282276
# San Antonio Spurs         3.282276
# Atlanta Hawks             3.282276
# Charlotte Hornets         3.282276
# Miami Heat                3.282276
# Washington Wizards        3.282276
# Denver Nuggets            3.282276
# Oklahoma City Thunder     3.282276
# ...

# %%
nba["Salary"].value_counts().sort_index(ascending = False)
# Out:
# Salary
# 50000000.0    1
# 45941000.0    1
# 45750000.0    1
# 44718728.0    1
# 44385460.0    1
#              ..
# 222888.0      2
# 222392.0      1
# 166794.0      1
# 111444.0      2
# 61776.0       1
# Name: count, Length: 309, dtype: int64

# %%
nba.dropna() #dropna creates a copy. Original dataset remains unaffected.
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary Testing       Sport
# ...

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary Testing       Sport
# ...

# %%
nba.dropna(subset = ["College", "Salary"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary Testing       Sport
# ...

# %%
nba = nba.fillna({
    "Name": "Chandradeep",
    "Team": "India",
    "Number": 100
})

# fillna method returns a copy and the original dataset remains unaffected.

# %%
nba # fillna method returns a copy and the original dataset remains unaffected.
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457    Chandradeep           India   100.0      NaN   NaN    NaN     NaN
#
#                College      Salary Testing       Sport
# ...

# %%
nba = nba.dropna(subset = "Salary") #A float column with NaN cannot be converted to int. So first drop NaN.
nba["Salary"].dtypes
# Out:
# dtype('float64')

# %%
nba["Salary"] = nba["Salary"].astype("int") #or we can simply use int with out ""
# Out:
# C:\Users\Chandradeep\AppData\Local\Temp\ipykernel_7272\2341104670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba["Salary"] = nba["Salary"].astype("int") #or we can simply use int with out ""

# %%
nba["Team"].value_counts().info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 30 entries, New Orleans Pelicans to Minnesota Timberwolves
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 30 non-null     int64
# dtypes: int64(1)
# memory usage: 480.0+ bytes

# %%
nba["Team"].astype("category").value_counts().info()
# Out:
# <class 'pandas.core.series.Series'>
# CategoricalIndex: 30 entries, New Orleans Pelicans to Minnesota Timberwolves
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 30 non-null     int64
# dtypes: int64(1)
# memory usage: 1.5 KB

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba.nunique()
# Out:
# Name        446
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       86
# College     115
# Salary      309
# Testing       1
# Sport         1
# dtype: int64

# %%
nba.sort_values(by = ["College","Team","Name"], ascending = [True, False, True], na_position = "first") 
#Returns a copy
# Out:
#                    Name                Team  Number Position   Age Height  \
# 373       Marcin Gortat  Washington Wizards    13.0        C  32.0   6-11
# 375        Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 445          Dante Exum           Utah Jazz    11.0       PG  20.0    6-6
# 450          Joe Ingles           Utah Jazz     2.0       SF  28.0    6-8
# 454           Raul Neto           Utah Jazz    25.0       PG  24.0    6-1
# ..                  ...                 ...     ...      ...   ...    ...
# 247          Sam Dekker     Houston Rockets     7.0       SF  22.0    6-9
# 231        Devin Harris    Dallas Mavericks    34.0       PG  33.0    6-3
# 331  Frank Kaminsky III   Charlotte Hornets    44.0        C  23.0    7-0
# 114     Larry Nance Jr.  Los Angeles Lakers     7.0       PF  23.0    6-9
# 308          David West   San Antonio Spurs    30.0       PF  35.0    6-9
#
#      Weight    College    Salary Testing       Sport
# ...

# %%
nba.sort_index(ascending = True) #Restore the original order.
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College    Salary Testing       Sport
# ...

# %%
nba.insert(0, "Salary Rank", value = nba["Salary"].rank(ascending = False))
nba.sort_values(by = "Salary Rank", ascending = True)
# Out:
#      Salary Rank                    Name                  Team  Number  \
# 109          1.0             Kobe Bryant    Los Angeles Lakers    24.0
# 169          2.0            LeBron James   Cleveland Cavaliers    23.0
# 33           3.0         Carmelo Anthony       New York Knicks     7.0
# 251          4.0           Dwight Howard       Houston Rockets    12.0
# 339          5.0              Chris Bosh            Miami Heat     1.0
# ..           ...                     ...                   ...     ...
# 175        442.0            Jordan McRae   Cleveland Cavaliers    12.0
# 135        443.0           Alan Williams          Phoenix Suns    15.0
# 130        444.5            Phil Pressey          Phoenix Suns    25.0
# 291        444.5         Orlando Johnson  New Orleans Pelicans     0.0
# 32         446.0  Thanasis Antetokounmpo       New York Knicks    43.0
#
#     Position   Age Height  Weight           College    Salary Testing  \
# ...
